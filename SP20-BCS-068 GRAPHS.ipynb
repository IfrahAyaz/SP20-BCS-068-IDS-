# %%
import networkx as nx
# !pip install python-louvain
import community as community_louvain
from networkx.algorithms.community.centrality import girvan_newman
# Out:
# Requirement already satisfied: python-louvain in c:\users\aa\anaconda3\lib\site-packages (0.16)
# Requirement already satisfied: numpy in c:\users\aa\anaconda3\lib\site-packages (from python-louvain) (1.21.5)
# Requirement already satisfied: networkx in c:\users\aa\anaconda3\lib\site-packages (from python-louvain) (2.7.1)

# %%
sG = nx.Graph()
dG = nx.DiGraph()

# %%
sG.add_node("A")
sG.add_node("B")
#sG.add_node("C")
sG.add_edge("A", "B")
nx.draw(sG, with_labels = True)
dG.add_node("A")
dG.add_node("B")
dG.add_node("C")

# %%
dG.add_edges_from([("A", "B"), ("B", "C"), ("C", "A")])

# %%
dG.add_edges_from([("A", "B", {"weight" : 3}), ("C", "A", {"weight" : 5})])

# %%
nx.draw(dG, with_labels = True)
