# %%
import matplotlib.pyplot as plt
years = range(2000, 2010)
apples = [0.3, 0.6, 0.9, 0.4, 0.65, 0.8,1.0,2.9,0.8,0.8]
plt.bar(years, apples)
plt.xlabel("Years")
plt.ylabel("Tons")
plt.show()

# %%
Makeup = ['Blush', 'Foundation', 'Highlighter', 'Lipstick', 'Mascara', 'Tint']
data = [35, 17, 20,9, 12, 42]
plt.pie(data, labels = Makeup, autopct='%1.1f%%')
plt.show()

# %%
data = np.random.normal(90, 50, 500)
plt.hist(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 data = np.random.normal(90, 50, 500)
#       2 plt.hist(data)
#       3 plt.show()
#
# NameError: name 'np' is not defined
